# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /home/rob/Desktop/lambda/labs/github/Notebooks

# %%
path = 'data/dataset.csv'

# %%
df = pd.read_csv(path)

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#         Id                                             Sudoku  \
# 0        0  8...74...1.........7.5.9.4....65.4..73.....296...
# 1        1  .5.....7.9......6...21.75.8.4..69.3...8...4......
# 2        2  ...45.2..3.........8....4..7...94.3.9..5.2.76....
# 3        3  9......31.3...8.....5.7.9..3...4...8.916..54.4...
# 4        4  9.......2784.1.5.....4.....2.53.1.7...7...8......
# ...    ...                                                ...
# 5024  5024  ..4...5.23...5...7.5.3...4.9..8.5..3....2....2...
# 5025  5025  .2..1..7.8..7.4..1..1.6.4..5.8.....6...8.9...1...
# 5026  5026  42.6.9.81....5..6....8.4...58......9..1...5..2...
# 5027  5027  .83...6..2..4.7..3.1.....5.6...2...7...765...3...
# 5028  5028  2...4...3.7.1.5.2....76.9...15....3.9.......1....
#
#                                                Solution       Level  People  \
# 0     8591742361648325973725698412916574837354186296...  Diabolical     254
# 1     8539461729175823644621375981458692376283754197...    Moderate     281
# 2     6974532183248617955819274637186945329435128762...  Diabolical     265
# 3     9274568316341982758153729643527496187916835424...       Tough     279
# 4     9615387427846125395234796182953814761479568236...    Moderate     301
# ...                                                 ...         ...     ...
# 5024  8147695323261548977593821469678452135389217642...  Diabolical    2145
# 5025  4265139788597243617319684525982417362638795141...    Moderate    2405
# 5026  4256793818192534673768149525837461296419325782...  Diabolical    2895
# 5027  7835916242654879139146327586591238478417653923...       Tough    3214
# 5028  2568491738791354263417629856159842379826735417...    Moderate    3132
#
#       Average-Time
# 0               25
# 1               12
# 2               22
# 3               19
# 4               14
# ...            ...
# 5024            41
# 5025            25
# 5026            37
# 5027            30
# 5028            26
#
# [5029 rows x 6 columns]

# %%
len(df)
# Out:
# 5029

# %%
from flask_sqlalchemy import SQLAlchemy

DB = SQLAlchemy()

class PuzzleTable(DB.Model):
    id = DB.Column(DB.Integer, primary_key=True)
    sudoku = DB.Column(DB.String(200), nullable=False)
    solution = DB.Column(DB.String(200), nullable=False)
    level = DB.Column(DB.String(200), nullable=False)
    people = DB.Column(DB.String(50), nullable=False)
    avg_time = DB.Column(DB.String(500), nullable=False)
    sudoku_hash = DB.Column(DB.String(100), nullable=False)

# %%
DB.create_all()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-53-06a1d097574d> in <module>
# ----> 1 DB.create_all()
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in create_all(self, bind, app)
#    1031            Parameters were added
#    1032         """
# -> 1033         self._execute_for_all_tables(app, bind, 'create_all')
#    1034
#    1035     def drop_all(self, bind='__all__', app=None):
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in _execute_for_all_tables(self, app, bind, operation, skip_tables)
#    1008
#    1009     def _execute_for_all_tables(self, app, bind, operation, skip_tables=False):
# -> 1010         app = self.get_app(app)
#    1011
#    1012         if bind == '__all__':
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in get_app(self, reference_app)
#     980
#     981         raise RuntimeError(
# --> 982             'No application found. Either work inside a view function or push'
#     983             ' an application context. See'
#     984             ' http://flask-sqlalchemy.pocoo.org/contexts/.'
#
# RuntimeError: No application found. Either work inside a view function or push an application context. See http://flask-sqlalchemy.pocoo.org/contexts/.

# %%
for i in range(len(df)):
    aid = df['Id'][i]
    asudoku = df['Sudoku'][i]
    asolution = df['Solution'][i]
    alevel = df['Level'][i]
    apeople = df['People'][i]
    aavg_time = df['Average-Time'][i]
    asudoku_hash = hashlib.md5(sudoku.encode('utf-8')).hexdigest()
    entry = PuzzleTable(id= aid,sudoku= asudoku,solution=asolution,level=alevel,people=apeople,avg_time=aavg_time,sudoku_hash=asudoku_hash)
    DB.session.add(entry)
    DB.session.commit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/sqlalchemy/util/_collections.py in __call__(self)
#    1009         try:
# -> 1010             return self.registry[key]
#    1011         except KeyError:
#
# KeyError: <greenlet.greenlet object at 0x7ff626e8aaa0>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-49-f1ea8048c6cd> in <module>
#       8     asudoku_hash = hashlib.md5(sudoku.encode('utf-8')).hexdigest()
#       9     entry = PuzzleTable(id= aid,sudoku= asudoku,solution=asolution,level=alevel,people=apeople,avg_time=aavg_time,sudoku_hash=asudoku_hash)
# ---> 10     DB.session.add(entry)
#      11     DB.session.commit()
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/sqlalchemy/orm/scoping.py in do(self, *args, **kwargs)
#     160 def instrument(name):
#     161     def do(self, *args, **kwargs):
# --> 162         return getattr(self.registry(), name)(*args, **kwargs)
#     163
#     164     return do
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/sqlalchemy/util/_collections.py in __call__(self)
#    1010             return self.registry[key]
#    1011         except KeyError:
# -> 1012             return self.registry.setdefault(key, self.createfunc())
#    1013
#    1014     def has(self):
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/sqlalchemy/orm/session.py in __call__(self, **local_kw)
#    3223             else:
#    3224                 local_kw.setdefault(k, v)
# -> 3225         return self.class_(**local_kw)
#    3226
#    3227     def configure(self, **new_kw):
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in __init__(self, db, autocommit, autoflush, **options)
#     134     def __init__(self, db, autocommit=False, autoflush=True, **options):
#     135         #: The application that this session belongs to.
# --> 136         self.app = app = db.get_app()
#     137         track_modifications = app.config['SQLALCHEMY_TRACK_MODIFICATIONS']
#     138         bind = options.pop('bind', None) or db.engine
#
# ~/anaconda3/envs/omega2020/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in get_app(self, reference_app)
#     980
#     981         raise RuntimeError(
# --> 982             'No application found. Either work inside a view function or push'
#     983             ' an application context. See'
#     984             ' http://flask-sqlalchemy.pocoo.org/contexts/.'
#
# RuntimeError: No application found. Either work inside a view function or push an application context. See http://flask-sqlalchemy.pocoo.org/contexts/.

# %%
entry
# Out:
# {'id': 0,
#  'sudoku': '8...74...1.........7.5.9.4....65.4..73.....296.8.......2.3.1.5.........8...9....2',
#  'solution': '859174236164832597372569841291657483735418629648293175926381754413725968587946312',
#  'level': 'Diabolical',
#  'people': 254,
#  'avg_time': 25,
#  'sudoku_hash': '118c816daed18bdd254a3b460ea3f8b9'}

# %%
entry[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-d205196076c3> in <module>
# ----> 1 entry[0]
#
# KeyError: 0
