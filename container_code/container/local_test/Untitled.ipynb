# %%
import pandas as pd

# %%
pd.read_csv('payload.csv',header=None)
# Out:
#       0    1    2    3
# 0   5.0  3.5  1.3  0.3
# 1   4.5  2.3  1.3  0.3
# 2   4.4  3.2  1.3  0.2
# 3   5.0  3.5  1.6  0.6
# 4   5.1  3.8  1.9  0.4
# 5   4.8  3.0  1.4  0.3
# 6   5.1  3.8  1.6  0.2
# 7   4.6  3.2  1.4  0.2
# 8   5.3  3.7  1.5  0.2
# 9   5.0  3.3  1.4  0.2
# 10  5.5  2.6  4.4  1.2
# 11  6.1  3.0  4.6  1.4
# 12  5.8  2.6  4.0  1.2
# 13  5.0  2.3  3.3  1.0
# 14  5.6  2.7  4.2  1.3
# 15  5.7  3.0  4.2  1.2
# 16  5.7  2.9  4.2  1.3
# 17  6.2  2.9  4.3  1.3
# 18  5.1  2.5  3.0  1.1
# 19  5.7  2.8  4.1  1.3
# 20  6.7  3.1  5.6  2.4
# 21  6.9  3.1  5.1  2.3
# 22  5.8  2.7  5.1  1.9
# 23  6.8  3.2  5.9  2.3
# 24  6.7  3.3  5.7  2.5
# 25  6.7  3.0  5.2  2.3
# 26  6.3  2.5  5.0  1.9
# 27  6.5  3.0  5.2  2.0
# 28  6.2  3.4  5.4  2.3

# %%
import cv2
im = cv2.imread("test_number.png")

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (28, 28)

# %%
test_df = pd.DataFrame(gray.flatten().reshape(-1,1)).T

# %%
test_df.to_csv('payload.csv')

# %%
import os
os.getcwd()
# Out:
# '/Users/rob/Desktop/lambda/labs/container_code/container/local_test'

# %%
# !ls
# Out:
# Untitled.ipynb    payload.csv       serve_local.sh    test_number.png
# payload-Copy1.csv predict.sh        test_dir          train_local.sh
